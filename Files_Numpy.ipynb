# %%
#TASK1
with open("warehouse_data.txt", "w") as file:
    file.write("120\n")
    file.write("85\n")
    file.write("200\n")
    file.write("95\n")
    file.write("150\n")
#If we use 'w' instead of 'a' while trying to add new data, it overwrites the file on second run, to append or add any new data we use 'a'

# %%
#TASK2
with open("warehouse_data.txt", "r") as file:
    context = [line.strip("\n") for line in file]
    print(context)

    #using readlines() to read all data at once, insead of read() or realine()
# Out:
# ['120', '85', '200', '95', '150']

# %%
#TASK3
import numpy as np

integers = np.array([78,89,90,92,87])
print(integers)
print("Datatype:",integers.dtype)
print("Shape:",integers.shape)
print("Size:",integers.size)


print("Sum:",integers.sum())
print("Max:",integers.max())
print("Min:",integers.min())

#if one of the value in array is 'error' , the dtype of whole array changes to string
# Out:
# [78 89 90 92 87]
# Datatype: int64
# Shape: (5,)
# Size: 5
# Sum: 436
# Max: 92
# Min: 78
